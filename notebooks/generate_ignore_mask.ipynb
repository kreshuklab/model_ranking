# %%
from model_ranking.utils import load_h5, save_h5
import numpy as np
from pathlib import Path

# %%
test_path = Path("/g/kreshuk/talks/data/Ovules/GT2x/test/")
test_files = sorted(test_path.glob("*.h5"))
for test_file in test_files:
    print(test_file.stem)
    data = load_h5(test_file, "label_with_ignore")
    ignore_mask = data == -1
    save_h5(test_file, "ignore_mask", ignore_mask.astype(np.uint8))
# Out:
# N_294_final_crop_ds2
# N_435_final_crop_ds2
# N_441_final_crop_ds2
# N_511_final_crop_ds2
# N_522_final_crop_ds2
# N_590_final_crop_ds2
# N_593_final_crop_ds2
