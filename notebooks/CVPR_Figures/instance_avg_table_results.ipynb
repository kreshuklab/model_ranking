# %%
import json
import numpy as np
from pathlib import Path

from model_ranking import (
    to_target_transfer_correlations,
    correlation_table,
    load_transfer_metric_results,
    avg_correlation_table,
    avg_correlation_to_latex,
    avg_correlation_to_latex_transposed,
    dataframe_to_latex_table_swapped,
)

# %%
mito_performance_path = "/g/kreshuk/talks/consistency_results/Instance_segmentation/Cells/transfer_results/consistency/fullslice_No_Ignore/transfer_performance_MAP_scores.json"
with open(mito_performance_path, "r") as f:
    mito_performance_scores = json.load(f)["performance_scores"]

# %%
nuclei_performance_path = "/g/kreshuk/talks/consistency_results/Instance_segmentation/nuclei/transfer_results/consistency/transfer_performance_MAP_scores.json"
with open(nuclei_performance_path, "r") as f:
    nuclei_performance_scores = json.load(f)["performance_scores"]

nuclei_performance_scores.pop("DSB2018", None)
# Out:
# {'BC_IN_model2': 0.4842800498008728,
#  'HN_IN_model2': 0.5206860899925232,
#  'Hst_IN_model3': 0.31693270802497864,
#  '895_IN_model2': 0.43998968601226807,
#  '1410_IN_model1': 0.49643415212631226}

# %% [markdown]
# # Gauss ARE

# %% [markdown]
# ### Mitochondria

# %%
base_path = "/g/kreshuk/talks/consistency_results/Instance_segmentation/Cells/transfer_results/consistency/fullslice_No_Ignore/ARE_consis"
#selected_augmentations = ["a001-005", "a005-01", "a01-015", "a015-02", "a02-025"]
selected_augmentations = ["a02-025"]

for aug in selected_augmentations:
    file_name = f"transfer_gauss_{aug}_Forg_ARE_scores.json"
    consistency_path = Path(base_path) / file_name
    results = load_transfer_metric_results(consistency_path)
    consistency_scores = results["transfer_scores"]
    targets = list(consistency_scores.keys())
    KT_scores, SP_scores, PE_scores = to_target_transfer_correlations(
        targets=targets,
        transfer_metric_per_target=consistency_scores,
        performance_per_target=mito_performance_scores,
        invert_transfer_metric=True,
    )
    df_mito_gauss_ARE = correlation_table(KT_scores, SP_scores, PE_scores, targets=targets, task='Cells')
    print(df_mito_gauss_ARE)
    df_mito_avg_gauss_ARE = avg_correlation_table(df_mito_gauss_ARE)
    print(df_mito_avg_gauss_ARE)
# Out:
# Loaded Transfer metric results from: /g/kreshuk/talks/consistency_results/Instance_segmentation/Cells/transfer_results/consistency/fullslice_No_Ignore/ARE_consis/transfer_gauss_a02-025_Forg_ARE_scores.json
#                  kt  kt pval  s rho  s rho pval    pr  pr pval
# Task  targets
# Cells FlyWing  0.57     0.07   0.76        0.03  0.94      0.0
#       Ovules   0.64     0.04   0.79        0.03  0.88      0.0
#       PNAS     0.86     0.00   0.93        0.00  0.87      0.0
#        KT_avg    KT_std    SR_avg    SR_std    PR_avg    PR_std
# Task
# Cells    0.69  0.151327  0.826667  0.090738  0.896667  0.037859

# %% [markdown]
# ### Nuclei

# %%
base_path = "/g/kreshuk/talks/consistency_results/Instance_segmentation/nuclei/transfer_results/consistency/gauss/ARE"
#selected_augmentations = ["a0-005", "a005-01", "a01-02"]
selected_augmentations = ["a01-02"]

for aug in selected_augmentations:
    file_name = f"transfer_Gauss_{aug}_Forg_ARE_scores.json"
    consistency_path = Path(base_path) / file_name
    results = load_transfer_metric_results(consistency_path)
    consistency_scores = results["transfer_scores"]
    consistency_scores.pop("DSB2018", None)
    targets = list(consistency_scores.keys())
    KT_scores, SP_scores, PE_scores = to_target_transfer_correlations(
        targets=targets,
        transfer_metric_per_target=consistency_scores,
        performance_per_target=nuclei_performance_scores,
        invert_transfer_metric=True,
        )
    df_nuclei_gauss_ARE = correlation_table(KT_scores, SP_scores, PE_scores, targets=targets)
    print(df_nuclei_gauss_ARE)
    df_nuclei_avg_gauss_ARE = avg_correlation_table(df_nuclei_gauss_ARE)
    print(df_nuclei_avg_gauss_ARE)
# Out:
# Loaded Transfer metric results from: /g/kreshuk/talks/consistency_results/Instance_segmentation/nuclei/transfer_results/consistency/gauss/ARE/transfer_Gauss_a01-02_Forg_ARE_scores.json
#                   kt  kt pval  s rho  s rho pval    pr  pr pval
# Task targets
# Mito BBBC039    0.40     0.47    0.6        0.40  0.50     0.39
#      Hoechst    1.00     0.03    1.0        0.02  0.93     0.02
#      S_BIAD895  0.67     0.33    0.8        0.33  0.94     0.06
#      S_BIAD634  0.80     0.09    0.9        0.10  0.79     0.11
#       KT_avg    KT_std  SR_avg    SR_std  PR_avg    PR_std
# Task
# Mito  0.7175  0.251446   0.825  0.170783    0.79  0.205102

# %% [markdown]
# # DO ARE

# %% [markdown]
# ### mitochondria

# %%
base_path = "/g/kreshuk/talks/consistency_results/Instance_segmentation/Cells/transfer_results/feature_perturbation_consistency/fullslice/ARE_consis"
#selected_augmentations = ["a0001", "a0005", "a001", "a002", "a003", "a004", "a005", "a01"]
selected_augmentations = ["a002"]

for aug in selected_augmentations:
    file_name = f"transfer_DO_{aug}_Forg_ARE_scores.json"
    consistency_path = Path(base_path) / file_name
    results = load_transfer_metric_results(consistency_path)
    consistency_scores = results["transfer_scores"]
    targets = list(consistency_scores.keys())
    KT_scores, SP_scores, PE_scores = to_target_transfer_correlations(
        targets=targets,
        transfer_metric_per_target=consistency_scores,
        performance_per_target=mito_performance_scores,
        invert_transfer_metric=True,
    )
    df_mito_DO_ARE = correlation_table(KT_scores, SP_scores, PE_scores, targets=targets, task='Cells')
    print(df_mito_DO_ARE)
    df_mito_avg_DO_ARE = avg_correlation_table(df_mito_DO_ARE)
    print(df_mito_avg_DO_ARE)
# Out:
# Loaded Transfer metric results from: /g/kreshuk/talks/consistency_results/Instance_segmentation/Cells/transfer_results/feature_perturbation_consistency/fullslice/ARE_consis/transfer_DO_a002_Forg_ARE_scores.json
#                  kt  kt pval  s rho  s rho pval    pr  pr pval
# Task  targets
# Cells FlyWing  0.64     0.04   0.79        0.03  0.94      0.0
#       Ovules   0.64     0.04   0.79        0.03  0.87      0.0
#       PNAS     0.79     0.01   0.90        0.00  0.92      0.0
#        KT_avg    KT_std    SR_avg    SR_std  PR_avg    PR_std
# Task
# Cells    0.69  0.086603  0.826667  0.063509    0.91  0.036056

# %% [markdown]
# ### Nuclei

# %%
base_path = "/g/kreshuk/talks/consistency_results/Instance_segmentation/nuclei/transfer_results/feature_perturbation_consistency/DO/ARE"
#selected_augmentations = ["a005", "a01", "a02", "a03", "a04", "a05"]
selected_augmentations = ["a02"]

for aug in selected_augmentations:
    file_name = f"transfer_DO_{aug}_Forg_ARE_scores.json"
    consistency_path = Path(base_path) / file_name
    results = load_transfer_metric_results(consistency_path)
    consistency_scores = results["transfer_scores"]
    consistency_scores.pop("DSB2018", None)
    targets = list(consistency_scores.keys())
    KT_scores, SP_scores, PE_scores = to_target_transfer_correlations(
        targets=targets,
        transfer_metric_per_target=consistency_scores,
        performance_per_target=nuclei_performance_scores,
        invert_transfer_metric=True,
        )

    df_nuclei_DO_ARE = correlation_table(KT_scores, SP_scores, PE_scores, targets=targets)
    print(df_nuclei_DO_ARE)
    df_nuclei_avg_DO_ARE = avg_correlation_table(df_nuclei_DO_ARE)
    print(df_nuclei_avg_DO_ARE)
# Out:
# Loaded Transfer metric results from: /g/kreshuk/talks/consistency_results/Instance_segmentation/nuclei/transfer_results/feature_perturbation_consistency/DO/ARE/transfer_DO_a02_Forg_ARE_scores.json
#                  kt  kt pval  s rho  s rho pval    pr  pr pval
# Task targets
# Mito BBBC039    0.4     0.46    0.5        0.45  0.95     0.02
#      Hoechst    1.0     0.02    1.0        0.03  0.93     0.02
#      S_BIAD895  1.0     0.08    1.0        0.08  0.72     0.28
#      S_BIAD634  0.8     0.08    0.9        0.07  0.78     0.12
#       KT_avg    KT_std  SR_avg    SR_std  PR_avg    PR_std
# Task
# Mito     0.8  0.282843    0.85  0.238048   0.845  0.112694

# %% [markdown]
# # Latex avg table

# %%
avg_dfs = [
    df_mito_avg_gauss_ARE,
    df_mito_avg_DO_ARE,
    df_nuclei_avg_gauss_ARE,
    df_nuclei_avg_DO_ARE,
]
metric_names = [
    "ARE",
    "ARE",
    "ARE",
    "ARE",
]
metric_specs = [
    "(Gauss)",
    "(DropOut)",
    "(Gauss)",
    "(DropOut)",
]

latex_table = avg_correlation_to_latex(
    df_avg_list=avg_dfs,
    metric_name_list=metric_names,
    metric_spec_list=metric_specs,
)
print(latex_table)
# Out:
# \begin{table}[htbp]
#     \centering
#     \setlength{\tabcolsep}{3pt}
#     \begin{tabular}{cc|ccc|ccc}
#     \hline
#     \multirow{2}{*}{Metric} & {} & \multicolumn{3}{c|}{Cells} & \multicolumn{3}{c}{Mito} \\
#  &  & K$\tau$ & S$\rho$ & P$r$ & K$\tau$ & S$\rho$ & P$r$ \\
# \hline
# \multirow{2}{*}{\begin{tabular}{@{}c@{}} ARE \\ ((Gauss))\end{tabular}} & \textbf{Avg.} & 0.69 & 0.83 & 0.90 & 0.72 & 0.83 & 0.79 \\
#  & \textbf{std.} & ±0.15 & ±0.09 & ±0.04 & ±0.25 & ±0.17 & ±0.21 \\
# \hline
# \multirow{2}{*}{\begin{tabular}{@{}c@{}} ARE \\ ((DropOut))\end{tabular}} & \textbf{Avg.} & 0.69 & 0.83 & 0.91 & 0.80 & 0.85 & 0.84 \\
#  & \textbf{std.} & ±0.09 & ±0.06 & ±0.04 & ±0.28 & ±0.24 & ±0.11 \\
# \hline
# \end{tabular}
# \caption{Correlation scores for multiple metrics}
# \label{tab:multiple_metrics}
# \end{table}

# %% [markdown]
# # Full Datasets

# %%
metric_names = ['ARE', 'ARE']
names2 = ['Gauss', 'DO']
correlation_dfs = [df_mito_gauss_ARE, df_mito_DO_ARE]
latex_table_swapped = dataframe_to_latex_table_swapped(correlation_dfs, metric_names, names2)
print(latex_table_swapped)
# Out:
# \begin{table*}[htbp]
# \centering
# \setlength{\tabcolsep}{3pt}
# \begin{tabular}{cc|cc|cc|cc}
# \hline
# \multirow{2}{*}{Metric} & {} & \multicolumn{2}{c|}{FlyWing} & \multicolumn{2}{c|}{Ovules} & \multicolumn{2}{c}{PNAS} \\
#  &  &  & \textbf{pval.} &  & \textbf{pval.} &  & \textbf{pval.} \\
# \hline
# \multirow{3}{*}{\begin{tabular}{@{}c@{}}ARE \\ Gauss\end{tabular}} & K$\tau$ & 0.57 & (0.1) & 0.64 & (0.0) & 0.86 & (0.0) \\
#  & S$\rho$ & 0.76 & (0.0) & 0.79 & (0.0) & 0.93 & (0.0) \\
#  & P$r$ & 0.94 & (0.0) & 0.88 & (0.0) & 0.87 & (0.0) \\
# \hline
# \multirow{3}{*}{\begin{tabular}{@{}c@{}}ARE \\ DO\end{tabular}} & K$\tau$ & 0.64 & (0.0) & 0.64 & (0.0) & 0.79 & (0.0) \\
#  & S$\rho$ & 0.79 & (0.0) & 0.79 & (0.0) & 0.90 & (0.0) \\
#  & P$r$ & 0.94 & (0.0) & 0.87 & (0.0) & 0.92 & (0.0) \\
# \hline
# \end{tabular}
# \caption{Correlation scores and p-values for Transfer metric correlations}
# \label{tab:transfer_metric_correlations_swapped}
# \end{table*}
