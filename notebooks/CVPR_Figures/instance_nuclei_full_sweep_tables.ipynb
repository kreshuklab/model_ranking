# %%
import json
from pathlib import Path
from typing import List
import pandas as pd
import numpy as np

from model_ranking import (
    to_target_transfer_correlations,
    correlation_table,
    load_transfer_metric_results,
    dataframe_to_latex_table_styled,
)

# %%
nuclei_performance_path = "/g/kreshuk/talks/consistency_results/Instance_segmentation/nuclei/transfer_results/consistency/transfer_performance_MAP_scores.json"
with open(nuclei_performance_path, "r") as f:
    nuclei_performance_scores = json.load(f)["performance_scores"]

nuclei_performance_scores.pop("DSB2018", None)
# Out:
# {'BC_IN_model2': 0.4842800498008728,
#  'HN_IN_model2': 0.5206860899925232,
#  'Hst_IN_model3': 0.31693270802497864,
#  '895_IN_model2': 0.43998968601226807,
#  '1410_IN_model1': 0.49643415212631226}

# %% [markdown]
# # Gauss ARS

# %%
base_path = "/g/kreshuk/talks/consistency_results/Instance_segmentation/nuclei/transfer_results/consistency/ARE"
selected_augmentations = ["a0-005", "a005-01", "a01-02"]

gauss_ARE_dfs: List[pd.DataFrame] = []

for aug in selected_augmentations:
    file_name = f"transfer_Gauss_{aug}_Forg_ARE_scores.json"
    consistency_path = Path(base_path) / file_name
    results = load_transfer_metric_results(consistency_path)
    consistency_scores = results["transfer_scores"]
    consistency_scores.pop("DSB2018", None)
    targets = list(consistency_scores.keys())
    KT_scores, SP_scores, PE_scores = to_target_transfer_correlations(
        targets=targets,
        transfer_metric_per_target=consistency_scores,
        performance_per_target=nuclei_performance_scores,
        invert_transfer_metric=True,
        )
    df_nuclei_gauss_ARE = correlation_table(KT_scores, SP_scores, PE_scores, targets=targets, task='Nuclei')
    print(df_nuclei_gauss_ARE)
    gauss_ARE_dfs.append(df_nuclei_gauss_ARE)
# Out:
# Loaded Transfer metric results from: /g/kreshuk/talks/consistency_results/Instance_segmentation/nuclei/transfer_results/consistency/ARE/transfer_Gauss_a0-005_Forg_ARE_scores.json
#                     kt  kt pval  s rho  s rho pval    pr  pr pval
# Task   targets
# Nuclei BBBC039    0.80     0.11    0.9        0.08  0.99     0.00
#        Hoechst    0.80     0.07    0.9        0.10  0.85     0.07
#        S_BIAD895  0.33     0.75    0.6        0.42  0.47     0.53
#        S_BIAD634  0.80     0.08    0.9        0.08  0.93     0.02
# Loaded Transfer metric results from: /g/kreshuk/talks/consistency_results/Instance_segmentation/nuclei/transfer_results/consistency/ARE/transfer_Gauss_a005-01_Forg_ARE_scores.json
#                     kt  kt pval  s rho  s rho pval    pr  pr pval
# Task   targets
# Nuclei BBBC039    0.20     0.83    0.5        0.42  0.72     0.17
#        Hoechst    0.80     0.11    0.9        0.07  0.89     0.04
# ...

# %%
metric_names= ['CTE-ARS']*len(selected_augmentations)
names2 = ['Gauss']*len(selected_augmentations)
names3 = [ f'({aug})' for aug in selected_augmentations]

latex_table= dataframe_to_latex_table_styled(
    gauss_ARE_dfs, 
    metric_names, 
    names2,
    names3,
    caption="CTE_ARS Correlation scores for Instance Segmentation of Nuclei with a range of Gaussian Input Perturbation Strengths. \textit{pval.} $<$ 0.05 (*), \textit{pval.} $<$ 0.01 (**).",
    label="tab:cte_ars_nuclei_gauss"
)
print(latex_table)
# Out:
# \begin{table}[tb]
# \centering
# \scriptsize
# \caption{CTE_ARS Correlation scores for Instance Segmentation of Nuclei with a range of Gaussian Input Perturbation Strengths. 	extit{pval.} $<$ 0.05 (*), 	extit{pval.} $<$ 0.01 (**).}
# \setlength{\tabcolsep}{3pt}
# \begin{tabular}{@{}c c
#    >{\columncolor{GreyTable}}c
#    >{\columncolor{GreyTable}}c
#    c c
#    >{\columncolor{GreyTable}}c
#    >{\columncolor{GreyTable}}c
#    c c@{}}
# \toprule
# \multirow{2}{*}{Metric} & {} & \multicolumn{2}{c}{BBBC039} & \multicolumn{2}{c}{Hoechst} & \multicolumn{2}{c}{S_BIAD895} & \multicolumn{2}{c}{S_BIAD634} \\
# &  &  \cellcolor{SecondaryColumnColor} & \cellcolor{SecondaryColumnColor}\textit{pval.} &  & \textit{pval.} &  \cellcolor{SecondaryColumnColor} & \cellcolor{SecondaryColumnColor}\textit{pval.} &  & \textit{pval.} \\
# \cmidrule{1-10}
# ...

# %% [markdown]
# # Gamma ARS

# %%
base_path = "/g/kreshuk/talks/consistency_results/Instance_segmentation/nuclei/transfer_results/consistency/ARE"
selected_augmentations = ["a08-09", "a09-095", "a105-11", "a11-12"]

gamma_ARE_dfs: List[pd.DataFrame] = []

for aug in selected_augmentations:
    file_name = f"transfer_Gamma_{aug}_Forg_ARE_scores.json"
    consistency_path = Path(base_path) / file_name
    results = load_transfer_metric_results(consistency_path)
    consistency_scores = results["transfer_scores"]
    consistency_scores.pop("DSB2018", None)
    targets = list(consistency_scores.keys())
    KT_scores, SP_scores, PE_scores = to_target_transfer_correlations(
        targets=targets,
        transfer_metric_per_target=consistency_scores,
        performance_per_target=nuclei_performance_scores,
        invert_transfer_metric=True,
        )
    df_nuclei_gamma_ARE = correlation_table(KT_scores, SP_scores, PE_scores, targets=targets, task='Nuclei')
    print(df_nuclei_gamma_ARE)
    gamma_ARE_dfs.append(df_nuclei_gamma_ARE)
# Out:
# Loaded Transfer metric results from: /g/kreshuk/talks/consistency_results/Instance_segmentation/nuclei/transfer_results/consistency/ARE/transfer_Gamma_a08-09_Forg_ARE_scores.json
#                     kt  kt pval  s rho  s rho pval    pr  pr pval
# Task   targets
# Nuclei BBBC039    0.40     0.42    0.6        0.37  0.62     0.26
#        Hoechst    0.80     0.08    0.9        0.10  0.82     0.09
#        S_BIAD895 -0.33     0.75   -0.4        0.75  0.06     0.94
#        S_BIAD634  0.40     0.49    0.6        0.36  0.64     0.25
# Loaded Transfer metric results from: /g/kreshuk/talks/consistency_results/Instance_segmentation/nuclei/transfer_results/consistency/ARE/transfer_Gamma_a09-095_Forg_ARE_scores.json
#                     kt  kt pval  s rho  s rho pval    pr  pr pval
# Task   targets
# Nuclei BBBC039    0.40     0.50    0.6        0.37  0.54     0.35
#        Hoechst    0.80     0.08    0.9        0.10  0.89     0.04
# ...

# %%
metric_names= ['CTE-ARS']*len(selected_augmentations)
names2 = ['Gamma']*len(selected_augmentations)
names3 = [ f'({aug})' for aug in selected_augmentations]

latex_table= dataframe_to_latex_table_styled(
    gamma_ARE_dfs, 
    metric_names, 
    names2,
    names3,
    caption="CTE_ARS Correlation scores for Instance Segmentation of Nuclei with a range of Gamma Input Perturbation Strengths. \textit{pval.} $<$ 0.05 (*), \textit{pval.} $<$ 0.01 (**).",
    label="tab:cte_ars_nuclei_gamma"
)
print(latex_table)
# Out:
# \begin{table}[tb]
# \centering
# \scriptsize
# \caption{CTE_ARS Correlation scores for Instance Segmentation of Nuclei with a range of Gamma Input Perturbation Strengths. 	extit{pval.} $<$ 0.05 (*), 	extit{pval.} $<$ 0.01 (**).}
# \setlength{\tabcolsep}{3pt}
# \begin{tabular}{@{}c c
#    >{\columncolor{GreyTable}}c
#    >{\columncolor{GreyTable}}c
#    c c
#    >{\columncolor{GreyTable}}c
#    >{\columncolor{GreyTable}}c
#    c c@{}}
# \toprule
# \multirow{2}{*}{Metric} & {} & \multicolumn{2}{c}{BBBC039} & \multicolumn{2}{c}{Hoechst} & \multicolumn{2}{c}{S_BIAD895} & \multicolumn{2}{c}{S_BIAD634} \\
# &  &  \cellcolor{SecondaryColumnColor} & \cellcolor{SecondaryColumnColor}\textit{pval.} &  & \textit{pval.} &  \cellcolor{SecondaryColumnColor} & \cellcolor{SecondaryColumnColor}\textit{pval.} &  & \textit{pval.} \\
# \cmidrule{1-10}
# ...

# %% [markdown]
# # Brightness ARS

# %%
base_path = "/g/kreshuk/talks/consistency_results/Instance_segmentation/nuclei/transfer_results/consistency/ARE"
selected_augmentations = ["a0-005", "a005-01", "a01-02"]

brt_ARE_dfs: List[pd.DataFrame] = []

for aug in selected_augmentations:
    file_name = f"transfer_Brt_{aug}_Forg_ARE_scores.json"
    consistency_path = Path(base_path) / file_name
    results = load_transfer_metric_results(consistency_path)
    consistency_scores = results["transfer_scores"]
    consistency_scores.pop("DSB2018", None)
    targets = list(consistency_scores.keys())
    KT_scores, SP_scores, PE_scores = to_target_transfer_correlations(
        targets=targets,
        transfer_metric_per_target=consistency_scores,
        performance_per_target=nuclei_performance_scores,
        invert_transfer_metric=True,
        )
    df_nuclei_brt_ARE = correlation_table(KT_scores, SP_scores, PE_scores, targets=targets, task='Nuclei')
    print(df_nuclei_brt_ARE)
    brt_ARE_dfs.append(df_nuclei_brt_ARE)
# Out:
# Loaded Transfer metric results from: /g/kreshuk/talks/consistency_results/Instance_segmentation/nuclei/transfer_results/consistency/ARE/transfer_Brt_a0-005_Forg_ARE_scores.json
#                    kt  kt pval  s rho  s rho pval    pr  pr pval
# Task   targets
# Nuclei BBBC039    0.6     0.22    0.7        0.25  0.80     0.10
#        Hoechst    0.6     0.26    0.7        0.21  0.83     0.08
#        S_BIAD895  0.0     1.00    0.2        0.92  0.77     0.23
#        S_BIAD634  0.8     0.10    0.9        0.09  0.72     0.17
# Loaded Transfer metric results from: /g/kreshuk/talks/consistency_results/Instance_segmentation/nuclei/transfer_results/consistency/ARE/transfer_Brt_a005-01_Forg_ARE_scores.json
#                     kt  kt pval  s rho  s rho pval    pr  pr pval
# Task   targets
# Nuclei BBBC039    0.40     0.46    0.6        0.32  0.69     0.19
#        Hoechst    0.80     0.11    0.9        0.10  0.92     0.03
#        S_BIAD895  0.33     0.75    0.4        0.75  0.80     0.20
# ...

# %%
metric_names= ['CTE-ARS']*len(selected_augmentations)
names2 = ['Brt']*len(selected_augmentations)
names3 = [ f'({aug})' for aug in selected_augmentations]

latex_table= dataframe_to_latex_table_styled(
    brt_ARE_dfs, 
    metric_names, 
    names2,
    names3,
    caption="CTE-ARS Correlation scores for Instance Segmentation of Nuclei with a range of Brightness Input Perturbation Strengths. \textit{pval.} $<$ 0.05 (*), \textit{pval.} $<$ 0.01 (**).",
    label="tab:cte_ars_nuclei_brt"
)
print(latex_table)
# Out:
# \begin{table}[tb]
# \centering
# \scriptsize
# \caption{CTE-ARS Correlation scores for Instance Segmentation of Nuclei with a range of Brightness Input Perturbation Strengths. 	extit{pval.} $<$ 0.05 (*), 	extit{pval.} $<$ 0.01 (**).}
# \setlength{\tabcolsep}{3pt}
# \begin{tabular}{@{}c c
#    >{\columncolor{GreyTable}}c
#    >{\columncolor{GreyTable}}c
#    c c
#    >{\columncolor{GreyTable}}c
#    >{\columncolor{GreyTable}}c
#    c c@{}}
# \toprule
# \multirow{2}{*}{Metric} & {} & \multicolumn{2}{c}{BBBC039} & \multicolumn{2}{c}{Hoechst} & \multicolumn{2}{c}{S_BIAD895} & \multicolumn{2}{c}{S_BIAD634} \\
# &  &  \cellcolor{SecondaryColumnColor} & \cellcolor{SecondaryColumnColor}\textit{pval.} &  & \textit{pval.} &  \cellcolor{SecondaryColumnColor} & \cellcolor{SecondaryColumnColor}\textit{pval.} &  & \textit{pval.} \\
# \cmidrule{1-10}
# ...

# %% [markdown]
# # Contrast ARS

# %%
base_path = "/g/kreshuk/talks/consistency_results/Instance_segmentation/nuclei/transfer_results/consistency/ARE"
selected_augmentations = ["a08-09", "a09-095", "a105-11", "a11-12"]

ctr_ARE_dfs: List[pd.DataFrame] = []

for aug in selected_augmentations:
    file_name = f"transfer_Ctr_{aug}_Forg_ARE_scores.json"
    consistency_path = Path(base_path) / file_name
    results = load_transfer_metric_results(consistency_path)
    consistency_scores = results["transfer_scores"]
    consistency_scores.pop("DSB2018", None)
    targets = list(consistency_scores.keys())
    KT_scores, SP_scores, PE_scores = to_target_transfer_correlations(
        targets=targets,
        transfer_metric_per_target=consistency_scores,
        performance_per_target=nuclei_performance_scores,
        invert_transfer_metric=True,
        )
    df_nuclei_ctr_ARE = correlation_table(KT_scores, SP_scores, PE_scores, targets=targets, task='Nuclei')
    print(df_nuclei_ctr_ARE)
    ctr_ARE_dfs.append(df_nuclei_ctr_ARE)
# Out:
# Loaded Transfer metric results from: /g/kreshuk/talks/consistency_results/Instance_segmentation/nuclei/transfer_results/consistency/ARE/transfer_Ctr_a08-09_Forg_ARE_scores.json
#                    kt  kt pval  s rho  s rho pval    pr  pr pval
# Task   targets
# Nuclei BBBC039    0.8     0.09    0.9        0.09  0.85     0.07
#        Hoechst    1.0     0.02    1.0        0.03  0.94     0.02
#        S_BIAD895  0.0     1.00   -0.2        0.92  0.18     0.82
#        S_BIAD634  0.8     0.08    0.9        0.07  0.83     0.08
# Loaded Transfer metric results from: /g/kreshuk/talks/consistency_results/Instance_segmentation/nuclei/transfer_results/consistency/ARE/transfer_Ctr_a09-095_Forg_ARE_scores.json
#                     kt  kt pval  s rho  s rho pval    pr  pr pval
# Task   targets
# Nuclei BBBC039    0.80     0.09    0.9        0.09  0.96     0.01
#        Hoechst    1.00     0.02    1.0        0.03  0.99     0.00
#        S_BIAD895  0.67     0.33    0.8        0.33  0.52     0.48
# ...

# %%
metric_names= ['CTE-ARS']*len(selected_augmentations)
names2 = ['Ctr']*len(selected_augmentations)
names3 = [ f'({aug})' for aug in selected_augmentations]

latex_table= dataframe_to_latex_table_styled(
    ctr_ARE_dfs, 
    metric_names, 
    names2,
    names3,
    caption="CTE-ARS Correlation scores for Instance Segmentation of Nuclei with a range of Contrast Input Perturbation Strengths. \textit{pval.} $<$ 0.05 (*), \textit{pval.} $<$ 0.01 (**).",
    label="tab:cte_ars_nuclei_ctr"
)
print(latex_table)
# Out:
# \begin{table}[tb]
# \centering
# \scriptsize
# \caption{CTE-ARS Correlation scores for Instance Segmentation of Nuclei with a range of Contrast Input Perturbation Strengths. 	extit{pval.} $<$ 0.05 (*), 	extit{pval.} $<$ 0.01 (**).}
# \setlength{\tabcolsep}{3pt}
# \begin{tabular}{@{}c c
#    >{\columncolor{GreyTable}}c
#    >{\columncolor{GreyTable}}c
#    c c
#    >{\columncolor{GreyTable}}c
#    >{\columncolor{GreyTable}}c
#    c c@{}}
# \toprule
# \multirow{2}{*}{Metric} & {} & \multicolumn{2}{c}{BBBC039} & \multicolumn{2}{c}{Hoechst} & \multicolumn{2}{c}{S_BIAD895} & \multicolumn{2}{c}{S_BIAD634} \\
# &  &  \cellcolor{SecondaryColumnColor} & \cellcolor{SecondaryColumnColor}\textit{pval.} &  & \textit{pval.} &  \cellcolor{SecondaryColumnColor} & \cellcolor{SecondaryColumnColor}\textit{pval.} &  & \textit{pval.} \\
# \cmidrule{1-10}
# ...

# %% [markdown]
# # DropOut ARE

# %%
base_path = "/g/kreshuk/talks/consistency_results/Instance_segmentation/nuclei/transfer_results/feature_perturbation_consistency/DO/ARE"
selected_augmentations = ["a005", "a01", "a02", "a03", "a04", "a05"]

DO_ARE_dfs: List[pd.DataFrame] = []

for aug in selected_augmentations:
    file_name = f"transfer_DO_{aug}_Forg_ARE_scores.json"
    consistency_path = Path(base_path) / file_name
    results = load_transfer_metric_results(consistency_path)
    consistency_scores = results["transfer_scores"]
    consistency_scores.pop("DSB2018", None)
    targets = list(consistency_scores.keys())
    KT_scores, SP_scores, PE_scores = to_target_transfer_correlations(
        targets=targets,
        transfer_metric_per_target=consistency_scores,
        performance_per_target=nuclei_performance_scores,
        invert_transfer_metric=True,
        )

    df_nuclei_DO_ARE = correlation_table(KT_scores, SP_scores, PE_scores, targets=targets, task='Nuclei')
    print(df_nuclei_DO_ARE)
    DO_ARE_dfs.append(df_nuclei_DO_ARE)
# Out:
# Loaded Transfer metric results from: /g/kreshuk/talks/consistency_results/Instance_segmentation/nuclei/transfer_results/feature_perturbation_consistency/DO/ARE/transfer_DO_a005_Forg_ARE_scores.json
#                    kt  kt pval  s rho  s rho pval    pr  pr pval
# Task   targets
# Nuclei BBBC039    0.4     0.43    0.6        0.32  0.83     0.08
#        Hoechst    0.8     0.08    0.9        0.08  0.90     0.04
#        S_BIAD895  1.0     0.08    1.0        0.08  0.93     0.07
#        S_BIAD634  0.8     0.12    0.9        0.08  0.88     0.05
# Loaded Transfer metric results from: /g/kreshuk/talks/consistency_results/Instance_segmentation/nuclei/transfer_results/feature_perturbation_consistency/DO/ARE/transfer_DO_a01_Forg_ARE_scores.json
#                    kt  kt pval  s rho  s rho pval    pr  pr pval
# Task   targets
# Nuclei BBBC039    0.4     0.51    0.5        0.44  0.87     0.05
#        Hoechst    1.0     0.01    1.0        0.03  0.86     0.06
# ...

# %%
metric_names= ['CTE-ARS']*len(selected_augmentations)
names2 = ['DropOut']*len(selected_augmentations)
names3 = [ f'({aug})' for aug in selected_augmentations]

latex_table= dataframe_to_latex_table_styled(
    DO_ARE_dfs, 
    metric_names, 
    names2,
    names3,
    caption="CTE_ARS Correlation scores for Instance Segmentation of Nuclei with a range of DropOut Perturbation Strengths. \textit{pval.} $<$ 0.05 (*), \textit{pval.} $<$ 0.01 (**).",
    label="tab:cte_ars_nuclei_dropout"
)
print(latex_table)
# Out:
# \begin{table}[tb]
# \centering
# \scriptsize
# \caption{CTE_ARS Correlation scores for Instance Segmentation of Nuclei with a range of DropOut Perturbation Strengths. 	extit{pval.} $<$ 0.05 (*), 	extit{pval.} $<$ 0.01 (**).}
# \setlength{\tabcolsep}{3pt}
# \begin{tabular}{@{}c c
#    >{\columncolor{GreyTable}}c
#    >{\columncolor{GreyTable}}c
#    c c
#    >{\columncolor{GreyTable}}c
#    >{\columncolor{GreyTable}}c
#    c c@{}}
# \toprule
# \multirow{2}{*}{Metric} & {} & \multicolumn{2}{c}{BBBC039} & \multicolumn{2}{c}{Hoechst} & \multicolumn{2}{c}{S_BIAD895} & \multicolumn{2}{c}{S_BIAD634} \\
# &  &  \cellcolor{SecondaryColumnColor} & \cellcolor{SecondaryColumnColor}\textit{pval.} &  & \textit{pval.} &  \cellcolor{SecondaryColumnColor} & \cellcolor{SecondaryColumnColor}\textit{pval.} &  & \textit{pval.} \\
# \cmidrule{1-10}
# ...

# %% [markdown]
# # Transfer Metrics Nuclei

# %%
transfer_metric_abbrevs = {
    "Transfer_Score": "TS",
    "LEEP": "LEEP",
    "NCTI": "NCTI",
    "LogME": "LogME",
    "Hscore": "Hscore",
    "GBC": "GBC",
    "Regularized_Hscore": "RegHscore",
    "Gaussian_LEEP": "NLEEP",
}

# %%
base_path = "/g/kreshuk/talks/sampled_features/semantic_segmentation/nuclei/1k_pixels_sampled/transfer_metric_results/direct_transfer_results"
result_paths = Path(base_path).glob("*.json")

transfer_metric_names_nuclei = []
transfer_metrics_dfs_nuclei = []
for result_path in result_paths:
    results = load_transfer_metric_results(result_path)
    correlation_scores = results["correlation_scores"]
    idx = 0
    per_target_KT = np.array(correlation_scores["KT"])
    per_target_SP = np.array(correlation_scores["SP"])
    per_target_PE = np.array(correlation_scores["PE"])
    df = correlation_table(
        per_target_KT, 
        per_target_SP, 
        per_target_PE, 
        targets = list(results['metadata']['targets']),
        task="Nuclei"
    )
    transfer_metric_name = '_'.join(result_path.stem.split("_")[1:])
    transfer_metric_abbrev = transfer_metric_abbrevs[transfer_metric_name]
    transfer_metric_names_nuclei.append(transfer_metric_abbrev)
    transfer_metrics_dfs_nuclei.append(df)
# Out:
# Loaded Transfer metric results from: /g/kreshuk/talks/sampled_features/semantic_segmentation/nuclei/1k_pixels_sampled/transfer_metric_results/direct_transfer_results/nuclei_GBC.json
# Experiment: nuclei_GBC
# Targets: 4 (BBBC039, DSB2018, Hoechst, S_BIAD895)
# Source models: 7
# Total transfers: 27
# Loaded Transfer metric results from: /g/kreshuk/talks/sampled_features/semantic_segmentation/nuclei/1k_pixels_sampled/transfer_metric_results/direct_transfer_results/nuclei_LEEP.json
# Experiment: nuclei_LEEP
# Targets: 4 (BBBC039, DSB2018, Hoechst, S_BIAD895)
# Source models: 7
# Total transfers: 27
# Loaded Transfer metric results from: /g/kreshuk/talks/sampled_features/semantic_segmentation/nuclei/1k_pixels_sampled/transfer_metric_results/direct_transfer_results/nuclei_Gaussian_LEEP.json
# Experiment: nuclei_Gaussian_LEEP
# Targets: 4 (BBBC039, DSB2018, Hoechst, S_BIAD895)
# Source models: 7
# Total transfers: 27
# ...

# %%
performance_path = "/g/kreshuk/talks/consistency_results/patch_segmentation/nuclei/transfer_results/ccfv/transfer_performance_F1_scores.json"
with open(performance_path, "r") as f:
    ccfv_nuclei_performance_scores = json.load(f)["performance_scores"]

# %%
base_path = "/g/kreshuk/talks/consistency_results/patch_segmentation/nuclei/transfer_results/ccfv"

file_name = f"transfer_CCFV_scores.json"
consistency_path = Path(base_path) / file_name
results = load_transfer_metric_results(consistency_path)
consistency_scores = results["transfer_scores"]
targets = list(consistency_scores.keys())
KT_scores, SP_scores, PE_scores = to_target_transfer_correlations(
    targets=targets,
    transfer_metric_per_target=consistency_scores,
    performance_per_target=ccfv_nuclei_performance_scores,
    )
df_nuclei_ccfv = correlation_table(KT_scores, SP_scores, PE_scores, targets=targets, task="Nuclei")
# Out:
# Loaded Transfer metric results from: /g/kreshuk/talks/consistency_results/patch_segmentation/nuclei/transfer_results/ccfv/transfer_CCFV_scores.json

# %%
dfs = [
    df_nuclei_ccfv,
] + transfer_metrics_dfs_nuclei

metric_names = [
    "CCFV",
] + transfer_metric_names_nuclei
latex_table = dataframe_to_latex_table_styled(
    dfs, 
    metric_names,
    caption="Transfer Metric Correlation scores for Semantic Segmentation of Nuclei with a range of Gaussian Input Perturbation Strengths. \textit{pval.} $<$ 0.05 (*), \textit{pval.} $<$ 0.01 (**).",
    label="tab:transfer_metric_nuclei_gauss"
)
print(latex_table)
# Out:
# \begin{table}[tb]
# \centering
# \scriptsize
# \caption{Transfer Metric Correlation scores for Semantic Segmentation of Nuclei with a range of Gaussian Input Perturbation Strengths. 	extit{pval.} $<$ 0.05 (*), 	extit{pval.} $<$ 0.01 (**).}
# \setlength{\tabcolsep}{3pt}
# \begin{tabular}{@{}c c
#    >{\columncolor{GreyTable}}c
#    >{\columncolor{GreyTable}}c
#    c c
#    >{\columncolor{GreyTable}}c
#    >{\columncolor{GreyTable}}c
#    c c@{}}
# \toprule
# \multirow{2}{*}{Metric} & {} & \multicolumn{2}{c}{BBBC039} & \multicolumn{2}{c}{DSB2018} & \multicolumn{2}{c}{Hoechst} & \multicolumn{2}{c}{S_BIAD895} \\
# &  &  \cellcolor{SecondaryColumnColor} & \cellcolor{SecondaryColumnColor}\textit{pval.} &  & \textit{pval.} &  \cellcolor{SecondaryColumnColor} & \cellcolor{SecondaryColumnColor}\textit{pval.} &  & \textit{pval.} \\
# \cmidrule{1-10}
# \multirow{3}{*}{CCFV} & K$\tau$ & 0.05 & (1.00) & 0.05 & (1.00) & 0.24 & (0.54) & -0.47 & (0.29) \\
# ...
