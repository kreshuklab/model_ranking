# %%
import matplotlib.pyplot as plt
import numpy as np
from model_ranking.utils import load_h5, get_roi_slice
from model_ranking import get_random_colors, get_unique_colourmap
from pytorch3dunet.augment.transforms import Normalize

# %% [markdown]
# # FlyWing

# %%
Fw_gt_path = "/scratch/talks/data/FlyWing/GT/test/per03.h5"
label_key = "volumes/labels/expanded_cells_with_ignore"
raw_key = "volumes/raw"

fw_gt = load_h5(Fw_gt_path, label_key)
fw_raw = load_h5(Fw_gt_path, raw_key)
fw_ignore = load_h5(Fw_gt_path, "volumes/labels/ignore")
print(fw_gt.shape, fw_raw.shape)
# Out:
# (160, 639, 765) (160, 639, 765)

# %%
i = 20
target = "FlyWing"



_ = plt.imshow(fw_raw[i, :512, :512].squeeze(), cmap='magma')
_ = plt.axis("off")
plt.tight_layout()
plt.savefig(f"/g/kreshuk/talks/model_ranking/notebooks/thesis/cells/example_data/{target}_raw.png", bbox_inches="tight", pad_inches=0, dpi=500)
plt.show()

_ = plt.imshow(fw_gt[i, :512, :512].squeeze(), cmap=get_unique_colourmap(fw_gt[i, :512, :512]), interpolation="nearest")
_ = plt.axis("off")
plt.tight_layout()
plt.savefig(f"/g/kreshuk/talks/model_ranking/notebooks/thesis/cells/example_data/{target}_inst_label.png", bbox_inches="tight", pad_inches=0, dpi=500)
plt.show()

# %% [markdown]
# # Ovules

# %%
OV_gt_path = "/scratch/talks/data/Ovules/GT2x/test/N_294_final_crop_ds2.h5"
label_key = "label_with_ignore"
raw_key = "raw"

OV_gt = load_h5(OV_gt_path, label_key)
OV_raw = load_h5(OV_gt_path, raw_key)
print(OV_gt.shape, OV_raw.shape)
# Out:
# (320, 960, 1000) (320, 960, 1000)

# %%
i = 220
target = "Ovules"



_ = plt.imshow(OV_raw[i, :512, :512].squeeze(), cmap='magma')
_ = plt.axis("off")
plt.tight_layout()
plt.savefig(f"/g/kreshuk/talks/model_ranking/notebooks/thesis/cells/example_data/{target}_raw.png", bbox_inches="tight", pad_inches=0, dpi=500)
plt.show()

_ = plt.imshow(OV_gt[i, :512, :512].squeeze(), cmap=get_unique_colourmap(OV_gt[i, :512, :512]), interpolation="nearest")
_ = plt.axis("off")
plt.tight_layout()
plt.savefig(f"/g/kreshuk/talks/model_ranking/notebooks/thesis/cells/example_data/{target}_inst_label.png", bbox_inches="tight", pad_inches=0, dpi=500)
plt.show()

# %% [markdown]
# # PNAS

# %%
PNAS_gt_path = "/scratch/talks/data/PNAS/test/36hrs_plant18_trim-acylYFP.h5"
gt = load_h5(PNAS_gt_path, "label")
raw = load_h5(PNAS_gt_path, "raw")
print(gt.shape, raw.shape)
# Out:
# (189, 512, 512) (189, 512, 512)

# %%
raw = Normalize(norm01=True)(raw)
raw.max(), raw.min()
# Out:
# (0.99999999995, 0.0)

# %%
i =100
target = "PNAS"



_ = plt.imshow(raw[i, :512, :512].squeeze(), cmap='magma', vmin=0., vmax=0.6)
_ = plt.axis("off")
plt.tight_layout()
plt.savefig(f"/g/kreshuk/talks/model_ranking/notebooks/thesis/cells/example_data/{target}_raw.png", bbox_inches="tight", pad_inches=0, dpi=500)
plt.show()

_ = plt.imshow(gt[i, :512, :512].squeeze(), cmap=get_unique_colourmap(gt[i, :512, :512]), interpolation="nearest")
_ = plt.axis("off")
plt.tight_layout()
plt.savefig(f"/g/kreshuk/talks/model_ranking/notebooks/thesis/cells/example_data/{target}_inst_label.png", bbox_inches="tight", pad_inches=0, dpi=500)
plt.show()

# %% [markdown]
# # Covid-IF

# %%
path = "/g/kreshuk/talks/data/covid_if/gt_image_025.h5"
raw = load_h5(path, "/raw/serum_IgG/s0")
gt = load_h5(path, "/labels/cells/s0")
print(raw.shape, gt.shape)
# Out:
# (1024, 1024) (1024, 1024)

# %%
i =100
target = "Covid-IF"



_ = plt.imshow(raw[:512, :512].squeeze(), cmap='magma')
_ = plt.axis("off")
plt.tight_layout()
plt.savefig(f"/g/kreshuk/talks/model_ranking/notebooks/thesis/cells/example_data/{target}_raw.png", bbox_inches="tight", pad_inches=0, dpi=500)
plt.show()

_ = plt.imshow(gt[:512, :512].squeeze(), cmap=get_unique_colourmap(gt[:512, :512]), interpolation="nearest")
_ = plt.axis("off")
plt.tight_layout()
plt.savefig(f"/g/kreshuk/talks/model_ranking/notebooks/thesis/cells/example_data/{target}_inst_label.png", bbox_inches="tight", pad_inches=0, dpi=500)
plt.show()
