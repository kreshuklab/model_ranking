# %%
import numpy as np
from numpy.typing import NDArray
from typing import Any
from typing import List, Dict
import matplotlib.pyplot as plt
from model_ranking import plot_multitarget_correlations
from model_ranking import get_summary_results, results_to_arrays

# %%
source_datasets = ["EPFL", "Hmito", "Rmito"]
targets = ["EPFL", "Hmito", "Rmito"]
### Only a single perturbation strength should be specified here at any one time
selected_augmentations = {
    "none": [""],
    "DO": ["a01"],
}
source_models = {
    "EPFL": "E_model4",
    "Hmito": "Hm_model3",
    "Rmito": "Rm_model3",
}
per_target_norms: Dict[str, List] = {
    "EPFL": ,
    "Hmito": ,
    "Rmito": ,
    "VNC": ,
}

result_folders = {
    "EPFL": "FP_3",
    "Hmito": "FP_3",
    "Rmito": "FP_3",
    "VNC": "resized",
}
consis_keys = {
    "EPFL": "HD_th05",
    "Hmito": "HD_th05",
    "Rmito": "HD_th05",
    "VNC": "HD_consis",
}
perf_key = "hard_f1"
approach="feature_perturbation_consistency"
consis_postfix="median_per_alpha"
perf_postfix="median"
base_result_path="/g/kreshuk/talks/consistency_results/patch_segmentation/mitochondria"

# %%
cmb_consis: Dict[str, NDArray[Any]] = {}
cmb_perf: Dict[str, NDArray[Any]] = {}
for target in targets:
    consis_str, _, NA_perf = get_summary_results(
        source_data=source_datasets,
        target_data=[target],
        source_models=source_models,
        selected_augmentations=selected_augmentations,
        selected_norms=per_target_norms,
        consis_keys=consis_keys,
        perf_key=perf_key,
        per_target_norms=True,
        result_folders=result_folders,
        approach=approach,
        consis_postfix=consis_postfix,
        perf_postfix=perf_postfix,
        base_seg_dir=base_result_path,
    )
    consis_scores, NA_perf_scores = results_to_arrays(
        consis_str,
        NA_perf,
        "DO",
        len(selected_augmentations["DO"]),
    )
    cmb_consis[target] = consis_scores.squeeze()
    cmb_perf[target] = NA_perf_scores.squeeze()
# Out:
# Source: EPFL
# 100%|██████████| 1/1 [00:00<00:00, 13.89it/s]
# Source: Hmito
# 100%|██████████| 1/1 [00:00<00:00, 16.54it/s]
# Source: Rmito
# 100%|██████████| 1/1 [00:00<00:00, 13.28it/s]
# Source: EPFL
# 100%|██████████| 1/1 [00:00<00:00, 16.63it/s]
# Source: Hmito
# 100%|██████████| 1/1 [00:00<00:00, 21.57it/s]
# Source: Rmito
# 100%|██████████| 1/1 [00:00<00:00, 17.78it/s]
# Source: EPFL
# 100%|██████████| 1/1 [00:00<00:00, 13.10it/s]
# Source: Hmito
# 100%|██████████| 1/1 [00:00<00:00, 10.31it/s]
# Source: Rmito
# 100%|██████████| 1/1 [00:00<00:00, 14.62it/s]

# %%
source_datasets = ["EPFL", "Hmito", "Rmito"]
targets = ["VNC"]
### Only a single perturbation strength should be specified here at any one time
selected_augmentations = {
    "none": [""],
    "DO": ["a01"],
}
source_models = {
    "EPFL": "E_model4",
    "Hmito": "Hm_model3",
    "Rmito": "Rm_model3",
}
per_target_norms: Dict[str, List] = {
    "EPFL": ,
    "Hmito": ,
    "Rmito": ,
    "VNC": ,
}

result_folders = {
    "EPFL": "FP_3",
    "Hmito": "FP_3",
    "Rmito": "FP_3",
    "VNC": "resized",
}
consis_keys = {
    "EPFL": "HD_th05",
    "Hmito": "HD_th05",
    "Rmito": "HD_th05",
    "VNC": "HD_consis",
}
perf_key = "hard_f1"
approach="feature_perturbation_consistency"
consis_postfix="median"
perf_postfix="median"

# %%
cmb_consis2: Dict[str, NDArray[Any]] = {}
cmb_perf2: Dict[str, NDArray[Any]] = {}
for target in targets:
    consis_str, _, NA_perf = get_summary_results(
        source_data=source_datasets,
        target_data=[target],
        source_models=source_models,
        selected_augmentations=selected_augmentations,
        selected_norms=per_target_norms,
        consis_keys=consis_keys,
        perf_key=perf_key,
        per_target_norms=True,
        result_folders=result_folders,
        approach=approach,
        consis_postfix=consis_postfix,
        perf_postfix=perf_postfix,
        base_seg_dir=base_result_path,
    )
    consis_scores, NA_perf_scores = results_to_arrays(
        consis_str,
        NA_perf,
        "DO",
        len(selected_augmentations["DO"]),
    )
    cmb_consis2[target] = consis_scores.squeeze()
    cmb_perf2[target] = NA_perf_scores.squeeze()
# Out:
# Source: EPFL
# 100%|██████████| 1/1 [00:00<00:00, 17.92it/s]
# Source: Hmito
# 100%|██████████| 1/1 [00:00<00:00, 19.31it/s]
# Source: Rmito
# 100%|██████████| 1/1 [00:00<00:00, 21.40it/s]

# %%
source_datasets = ["VNC"]
targets = ["EPFL", "Hmito", "Rmito"]
### Only a single perturbation strength should be specified here at any one time
selected_augmentations = {
    "none": [""],
    "DO": ["a01"],
}
source_models = {
    "EPFL": "E_model4",
    "Hmito": "Hm_model3",
    "Rmito": "Rm_model3",
    "VNC": "V_model1",
}
per_target_norms: Dict[str, List] = {
    "EPFL": ,
    "Hmito": ,
    "Rmito": ,
    "VNC": ,
}

result_folders = {
    "EPFL": "FP_3",
    "Hmito": "FP_3",
    "Rmito": "FP_3",
    "VNC": "resized",
}
consis_keys = {
    "EPFL": "HD_consis",
    "Hmito": "HD_consis",
    "Rmito": "HD_consis",
    "VNC": "HD_consis",
}
perf_key = "hard_f1"
approach="feature_perturbation_consistency"
consis_postfix="median"
perf_postfix="median"

# %%
cmb_consis3: Dict[str, NDArray[Any]] = {}
cmb_perf3: Dict[str, NDArray[Any]] = {}
for target in targets:
    consis_str, _, NA_perf = get_summary_results(
        source_data=source_datasets,
        target_data=[target],
        source_models=source_models,
        selected_augmentations=selected_augmentations,
        selected_norms=per_target_norms,
        consis_keys=consis_keys,
        perf_key=perf_key,
        per_target_norms=True,
        result_folders=result_folders,
        approach=approach,
        consis_postfix=consis_postfix,
        perf_postfix=perf_postfix,
        base_seg_dir=base_result_path,
    )
    consis_scores, NA_perf_scores = results_to_arrays(
        consis_str,
        NA_perf,
        "DO",
        len(selected_augmentations["DO"]),
    )
    cmb_consis3[target] = consis_scores.squeeze()
    cmb_perf3[target] = NA_perf_scores.squeeze()
# Out:
# Source: VNC
# 100%|██████████| 1/1 [00:00<00:00, 14.32it/s]
# Source: VNC
# 100%|██████████| 1/1 [00:00<00:00, 18.23it/s]
# Source: VNC
# 100%|██████████| 1/1 [00:00<00:00, 14.13it/s]

# %%
cmb_consis2["VNC"]
# Out:
# array([0.108427  , 0.11768509, 0.26255521])

# %%
for target in cmb_consis.keys():
    cmb_consis[target] = np.concatenate([cmb_consis[target], np.atleast_1d(cmb_consis3[target])])
    cmb_perf[target] = np.concatenate([cmb_perf[target], np.atleast_1d(cmb_perf3[target])])
    print(f"Target: {target}")
    print(f"Consistency scores: {cmb_consis[target]}")
    print(f"Performance scores: {cmb_perf[target]}")
# Out:
# Target: EPFL
# Consistency scores: [0.00794433 0.03185725 0.1314703  0.08957435]
# Performance scores: [0.94850278 0.87699091 0.69233453 0.71236527]
# Target: Hmito
# Consistency scores: [0.10194805 0.01662118 0.04498506 0.13110831]
# Performance scores: [0.37838694 0.95249295 0.84691751 0.45050278]
# Target: Rmito
# Consistency scores: [0.13472222 0.03488658 0.01024632 0.16984034]
# Performance scores: [0.24683729 0.88592064 0.96010637 0.27781898]

# %%
# Combine cmb_consis and cmb_consis2 into a single dictionary
cmb_consis_combined = {**cmb_consis, **cmb_consis2}
cmb_perf_combined = {**cmb_perf, **cmb_perf2}

# %%
plot_multitarget_correlations(
    cmb_consis_combined ,
    cmb_perf_combined ,
    xlim=(0.3,1),
    perf_metric_name="F1 score",
)

# %%
cmb_consis['EPFL']
# Out:
# array([0.00541712, 0.02117597, 0.08141668])
