# %%
from typing import Dict, List

from model_ranking.results import get_summary_results
from model_ranking.plots import plot_alpha_sweep_specific_norm

# %% [markdown]
# # VNC Target Consistency

# %%
source_datasets = ["EPFL", "Hmito", "Rmito"]
targets = ["VNC"]
### Only a single perturbation strength should be specified here at any one time
selected_augmentations = {
    "none": [""],
    "DO": ["a0005", "a001", "a005", "a01", "a02", "a03", "a04", "a05"],
}
source_models = {
    "EPFL": "E_model4",
    "Hmito": "Hm_model3",
    "Rmito": "Rm_model3",
}
per_target_norms: Dict[str, List[None]] = {
    "EPFL": [None],
    "Hmito": [None],
    "Rmito": [None],
    "VNC": [None],
}

result_folders = {
    "VNC": "resized",
}
consis_keys = {
    "VNC": "HD_consis",
}
perf_key = "hard_f1"
approach="feature_perturbation_consistency"
consis_postfix="median"
perf_postfix="median"
base_result_path = "/g/kreshuk/talks/consistency_results/patch_segmentation/mitochondria"

# %%
for target in targets:
    consis_str, _, NA_perf = get_summary_results(
        source_data=source_datasets,
        target_data=[target],
        source_models=source_models,
        selected_augmentations=selected_augmentations,
        selected_norms=per_target_norms,
        consis_keys=consis_keys,
        perf_key=perf_key,
        per_target_norms=True,
        result_folders=result_folders,
        approach=approach,
        consis_postfix=consis_postfix,
        perf_postfix=perf_postfix,
        base_seg_dir=base_result_path,
    )
    plot_alpha_sweep_specific_norm(
        consis_str,
        NA_perf,
        augs=["DO"],
        select_alphas=selected_augmentations,
        select_norms=per_target_norms,
        consistency_metric_name="Inverted HD",
        invert_consis_metric= True,
        invert_perf_metric=False,
        pos_correlation_line=False,
        per_transfer_norms=False,
        xlim=(0, 1),
        n_rows=1,
        n_cols = 1,
    )
# Out:
# Source: EPFL
# 100%|██████████| 1/1 [00:00<00:00, 17.86it/s]
# Source: Hmito
# 100%|██████████| 1/1 [00:00<00:00, 16.16it/s]
# Source: Rmito
# 100%|██████████| 1/1 [00:00<00:00, 20.81it/s]

# %% [markdown]
# ### EI Consistency

# %%
consis_keys = {
    "VNC": "EI_consis",
}


for target in targets:
    consis_str, _, NA_perf = get_summary_results(
        source_data=source_datasets,
        target_data=[target],
        source_models=source_models,
        selected_augmentations=selected_augmentations,
        selected_norms=per_target_norms,
        consis_keys=consis_keys,
        perf_key=perf_key,
        per_target_norms=True,
        result_folders=result_folders,
        approach=approach,
        consis_postfix=consis_postfix,
        perf_postfix=perf_postfix,
        base_seg_dir=base_result_path,
    )
    plot_alpha_sweep_specific_norm(
        consis_str,
        NA_perf,
        augs=["DO"],
        select_alphas=selected_augmentations,
        select_norms=per_target_norms,
        consistency_metric_name="EI",
        invert_consis_metric= False,
        invert_perf_metric=False,
        pos_correlation_line=False,
        per_transfer_norms=False,
        xlim=(0, 1),
        n_rows=1,
        n_cols = 1,
    )
# Out:
# Source: EPFL
# 100%|██████████| 1/1 [00:00<00:00, 22.08it/s]
# Source: Hmito
# 100%|██████████| 1/1 [00:00<00:00, 20.91it/s]
# Source: Rmito
# 100%|██████████| 1/1 [00:00<00:00, 24.14it/s]

# %% [markdown]
# # Hmito Target consistency

# %%
source_datasets = ["EPFL", "Hmito", "Rmito"]
targets = ["Hmito"]
### Only a single perturbation strength should be specified here at any one time
selected_augmentations = {
    "none": [""],
    "DO": ["a0005", "a001", "a005", "a01", "a02", "a03", "a04"],
}
source_models = {
    "EPFL": "E_model4",
    "Hmito": "Hm_model3",
    "Rmito": "Rm_model3",
    "VNC": "V_model1",
}
per_target_norms: Dict[str, List[None]] = {
    "EPFL": [None],
    "Hmito": [None],
    "Rmito": [None],
    "VNC": [None],
}

result_folders = {
    "Hmito": "FP_3",
}
consis_keys = {
    "Hmito": "HD_th05",
}
perf_key = "hard_f1"
approach="feature_perturbation_consistency"
consis_postfix="median_per_alpha"
perf_postfix="median"
base_result_path = "/g/kreshuk/talks/consistency_results/patch_segmentation/mitochondria"

# %%
for target in targets:
    consis_str, _, NA_perf = get_summary_results(
        source_data=source_datasets,
        target_data=[target],
        source_models=source_models,
        selected_augmentations=selected_augmentations,
        selected_norms=per_target_norms,
        consis_keys=consis_keys,
        perf_key=perf_key,
        per_target_norms=True,
        result_folders=result_folders,
        approach=approach,
        consis_postfix=consis_postfix,
        perf_postfix=perf_postfix,
        base_seg_dir=base_result_path,
    )
    consis_str_VNC, _, NA_per_VNC = get_summary_results(
        source_data=["VNC"],
        target_data=[target],
        source_models=source_models,
        selected_augmentations=selected_augmentations,
        selected_norms=per_target_norms,
        consis_keys={"Hmito": "HD_consis"},
        perf_key=perf_key,
        per_target_norms=True,
        result_folders=result_folders,
        approach=approach,
        consis_postfix="median",
        perf_postfix=perf_postfix,
        base_seg_dir=base_result_path,
    )
    consis_str.update(consis_str_VNC)
    NA_perf.update(NA_per_VNC)
    plot_alpha_sweep_specific_norm(
        consis_str,
        NA_perf,
        augs=["DO"],
        select_alphas=selected_augmentations,
        select_norms=per_target_norms,
        consistency_metric_name="Inverted HD",
        invert_consis_metric= True,
        invert_perf_metric=False,
        pos_correlation_line=False,
        per_transfer_norms=False,
        xlim=(0, 1),
        n_rows=1,
        n_cols = 1,
    )
# Out:
# Source: EPFL
# 100%|██████████| 1/1 [00:00<00:00, 28.71it/s]
# Source: Hmito
# 100%|██████████| 1/1 [00:00<00:00, 29.08it/s]
# Source: Rmito
# 100%|██████████| 1/1 [00:00<00:00, 27.79it/s]
# Source: VNC
# 100%|██████████| 1/1 [00:00<00:00,  9.75it/s]

# %% [markdown]
# # Rmito Target Consistency

# %%
source_datasets = ["EPFL", "Hmito", "Rmito"]
targets = ["Rmito"]
### Only a single perturbation strength should be specified here at any one time
selected_augmentations = {
    "none": [""],
    "DO": ["a0005", "a001", "a005", "a01", "a02", "a03", "a04"],
}
source_models = {
    "EPFL": "E_model4",
    "Hmito": "Hm_model3",
    "Rmito": "Rm_model3",
    "VNC": "V_model1",
}
per_target_norms: Dict[str, List[None]] = {
    "EPFL": [None],
    "Hmito": [None],
    "Rmito": [None],
    "VNC": [None],
}

result_folders = {
    "Rmito": "FP_3",
}
consis_keys = {
    "Rmito": "HD_th05",
}
perf_key = "hard_f1"
approach="feature_perturbation_consistency"
consis_postfix="median_per_alpha"
perf_postfix="median"
base_result_path = "/g/kreshuk/talks/consistency_results/patch_segmentation/mitochondria"

# %%
for target in targets:
    consis_str, _, NA_perf = get_summary_results(
        source_data=source_datasets,
        target_data=[target],
        source_models=source_models,
        selected_augmentations=selected_augmentations,
        selected_norms=per_target_norms,
        consis_keys=consis_keys,
        perf_key=perf_key,
        per_target_norms=True,
        result_folders=result_folders,
        approach=approach,
        consis_postfix=consis_postfix,
        perf_postfix=perf_postfix,
        base_seg_dir=base_result_path,
    )
    consis_str_VNC, _, NA_per_VNC = get_summary_results(
        source_data=["VNC"],
        target_data=[target],
        source_models=source_models,
        selected_augmentations=selected_augmentations,
        selected_norms=per_target_norms,
        consis_keys={"Rmito": "HD_consis"},
        perf_key=perf_key,
        per_target_norms=True,
        result_folders=result_folders,
        approach=approach,
        consis_postfix="median",
        perf_postfix=perf_postfix,
        base_seg_dir=base_result_path,
    )
    consis_str.update(consis_str_VNC)
    NA_perf.update(NA_per_VNC)
    plot_alpha_sweep_specific_norm(
        consis_str,
        NA_perf,
        augs=["DO"],
        select_alphas=selected_augmentations,
        select_norms=per_target_norms,
        consistency_metric_name="Inverted HD",
        invert_consis_metric= True,
        invert_perf_metric=False,
        pos_correlation_line=False,
        per_transfer_norms=False,
        xlim=(0, 1),
        n_rows=1,
        n_cols = 1,
    )
# Out:
# Source: EPFL
# 100%|██████████| 1/1 [00:00<00:00, 30.08it/s]
# Source: Hmito
# 100%|██████████| 1/1 [00:00<00:00, 33.26it/s]
# Source: Rmito
# 100%|██████████| 1/1 [00:00<00:00, 31.77it/s]
# Source: VNC
# 100%|██████████| 1/1 [00:00<00:00,  4.84it/s]

# %% [markdown]
# # EPFL Target Consistency

# %%
source_datasets = ["EPFL", "Hmito", "Rmito"]
targets = ["EPFL"]
### Only a single perturbation strength should be specified here at any one time
selected_augmentations = {
    "none": [""],
    "DO": ["a0005", "a001", "a005", "a01", "a02", "a03", "a04"],
}
source_models = {
    "EPFL": "E_model4",
    "Hmito": "Hm_model3",
    "Rmito": "Rm_model3",
    "VNC": "V_model1",
}
per_target_norms: Dict[str, List[None]] = {
    "EPFL": [None],
    "Hmito": [None],
    "Rmito": [None],
    "VNC": [None],
}

result_folders = {
    "EPFL": "FP_3",
}
consis_keys = {
    "EPFL": "HD_th05",
}
perf_key = "hard_f1"
approach="feature_perturbation_consistency"
consis_postfix="median_per_alpha"
perf_postfix="median"
base_result_path = "/g/kreshuk/talks/consistency_results/patch_segmentation/mitochondria"

# %%
for target in targets:
    consis_str, _, NA_perf = get_summary_results(
        source_data=source_datasets,
        target_data=[target],
        source_models=source_models,
        selected_augmentations=selected_augmentations,
        selected_norms=per_target_norms,
        consis_keys=consis_keys,
        perf_key=perf_key,
        per_target_norms=True,
        result_folders=result_folders,
        approach=approach,
        consis_postfix=consis_postfix,
        perf_postfix=perf_postfix,
        base_seg_dir=base_result_path,
    )
    consis_str_VNC, _, NA_per_VNC = get_summary_results(
        source_data=["VNC"],
        target_data=[target],
        source_models=source_models,
        selected_augmentations=selected_augmentations,
        selected_norms=per_target_norms,
        consis_keys={"EPFL": "HD_consis"},
        perf_key=perf_key,
        per_target_norms=True,
        result_folders=result_folders,
        approach=approach,
        consis_postfix="median",
        perf_postfix=perf_postfix,
        base_seg_dir=base_result_path,
    )
    consis_str.update(consis_str_VNC)
    NA_perf.update(NA_per_VNC)
    plot_alpha_sweep_specific_norm(
        consis_str,
        NA_perf,
        augs=["DO"],
        select_alphas=selected_augmentations,
        select_norms=per_target_norms,
        consistency_metric_name="Inverted HD",
        invert_consis_metric= True,
        invert_perf_metric=False,
        pos_correlation_line=False,
        per_transfer_norms=False,
        xlim=(0, 1),
        n_rows=1,
        n_cols = 1,
    )
# Out:
# Source: EPFL
# 100%|██████████| 1/1 [00:00<00:00, 23.83it/s]
# Source: Hmito
# 100%|██████████| 1/1 [00:00<00:00, 24.27it/s]
# Source: Rmito
# 100%|██████████| 1/1 [00:00<00:00, 24.83it/s]
# Source: VNC
# 100%|██████████| 1/1 [00:00<00:00,  6.30it/s]
