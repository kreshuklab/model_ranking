# %%
from model_ranking import load_h5
import matplotlib.pyplot as plt
import numpy as np

# %%
path_p = "/g/kreshuk/talks/consistency_results/patch_segmentation/mitochondria/EPFL_to_EPFL_gap/feature_perturbation_consistency/FP_full/E_model_Unetr2/norm_Normalize/DO_a01/predictions/test_predictions.h5"
path_unp = "/g/kreshuk/talks/consistency_results/patch_segmentation/mitochondria/EPFL_to_EPFL_gap/feature_perturbation_consistency/FP_full/E_model_Unetr2/norm_Normalize/none/predictions/test_predictions.h5"

seg_p = load_h5(path_p, "predictions")
seg_unp = load_h5(path_unp, "predictions")
consis_score = load_h5(path_p, "EI_consis")

# %%
plt.hist(consis_score.ravel(), bins=100)
plt.axvline(np.nanmean(consis_score), color='r')
plt.show()
