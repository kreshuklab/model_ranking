# %%
from pathlib import Path

from model_ranking import (
    load_transfer_metric_results,
    match_model_names,
    plot_performance_vs_transfer_metric_multi_target,
    to_target_transfer_correlations,
    correlation_table,
)
# Out:
# INFO: P [MainThread] 2025-08-20 08:57:38,757 plantseg - Logger configured at initialisation. PlantSeg logger name: plantseg
# /g/kreshuk/talks/pytorch-3dunet/pytorch3dunet/unet3d/predictor.py:22: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
performance_path = "/scratch/talks/sampled_features/semantic_segmentation/mitochondria/transfer_metric_results/combined_finetuned_results/finetuned_combined_GBC.json"
results = load_transfer_metric_results(performance_path)
performance_scores = results["performance_scores"]
# Out:
# Loaded Transfer metric results from: /scratch/talks/sampled_features/semantic_segmentation/mitochondria/transfer_metric_results/combined_finetuned_results/finetuned_combined_GBC.json
# Experiment: finetuned_combined_GBC
# Targets: 4 (EPFL, Hmito, Rmito, VNC)
# Source models: 45
# Total transfers: 45

# %%
base_path = Path("/scratch/talks/sampled_features/semantic_segmentation/mitochondria/transfer_metric_results")
transfer_metrics = ["GBC", "LEEP", "Gaussian_LEEP", "Hscore", "Regularized_Hscore", "NCTI", "LogME"]

for transfer_metric in transfer_metrics:
    path = base_path / f"mitochondria_{transfer_metric}.json"
    results = load_transfer_metric_results(path)
    targets = results['metadata']['targets']
    transfer_scores = results["transfer_scores"]
    transfer_scores = match_model_names(
        performance_scores=performance_scores,
        transfer_scores=transfer_scores,
    )
    plot_performance_vs_transfer_metric_multi_target(
        transfer_scores=transfer_scores,
        performance_scores=performance_scores,
        transfer_metric=transfer_metric
    )
    KT_scores, SP_scores, PE_scores = to_target_transfer_correlations(
        targets=targets,
        transfer_metric_per_target=transfer_scores,
        performance_per_target=performance_scores,
    )
    correlation_df = correlation_table(KT_scores, SP_scores, PE_scores, targets=targets)
    print(correlation_df)
# Out:
# Loaded Transfer metric results from: /scratch/talks/sampled_features/semantic_segmentation/mitochondria/transfer_metric_results/mitochondria_GBC.json
# Experiment: mitochondria_GBC
# Targets: 4 (EPFL, Hmito, Rmito, VNC)
# Source models: 15
# Total transfers: 57
# Info: No match found for transfer model 'E_model5' in target 'EPFL' - removing from result
# Info: No match found for transfer model 'E_model_NA2' in target 'EPFL' - removing from result
# Info: No match found for transfer model 'E_model_Res1' in target 'EPFL' - removing from result
# Info: No match found for transfer model 'E_model_Unetr2' in target 'EPFL' - removing from result
# Info: No match found for transfer model 'Hm_model4' in target 'Hmito' - removing from result
# Info: No match found for transfer model 'Hm_model_NA2' in target 'Hmito' - removing from result
# Info: No match found for transfer model 'Hm_model_Res1' in target 'Hmito' - removing from result
# Info: No match found for transfer model 'Hm_model_Unetr2' in target 'Hmito' - removing from result
# Info: No match found for transfer model 'Rm_model4' in target 'Rmito' - removing from result
# Info: No match found for transfer model 'Rm_model_NA2' in target 'Rmito' - removing from result
# Info: No match found for transfer model 'Rm_model_Res1' in target 'Rmito' - removing from result
# Info: No match found for transfer model 'Rm_model_Unetr2' in target 'Rmito' - removing from result
# Processing: GBC
# Number of targets: 4
#   Target 1: EPFL
#   Target 2: Hmito
#   Target 3: Rmito
#   Target 4: VNC
#                 kt  kt pval  s rho  s rho pval    pr  pr pval
# Task targets
# Mito EPFL     0.24     0.47   0.47        0.15  0.31     0.19
#      Hmito    0.53     0.10   0.25        0.43  0.20     0.43
#      Rmito    0.41     0.22   0.48        0.13  0.45     0.06
#      VNC      0.45     0.14   0.28        0.40  0.24     0.33
# Loaded Transfer metric results from: /scratch/talks/sampled_features/semantic_segmentation/mitochondria/transfer_metric_results/mitochondria_LEEP.json
# Experiment: mitochondria_LEEP
# Targets: 4 (EPFL, Hmito, Rmito, VNC)
# Source models: 15
# Total transfers: 57
# Info: No match found for transfer model 'E_model5' in target 'EPFL' - removing from result
# Info: No match found for transfer model 'E_model_NA2' in target 'EPFL' - removing from result
# Info: No match found for transfer model 'E_model_Res1' in target 'EPFL' - removing from result
# Info: No match found for transfer model 'E_model_Unetr2' in target 'EPFL' - removing from result
# Info: No match found for transfer model 'Hm_model4' in target 'Hmito' - removing from result
# Info: No match found for transfer model 'Hm_model_NA2' in target 'Hmito' - removing from result
# Info: No match found for transfer model 'Hm_model_Res1' in target 'Hmito' - removing from result
# Info: No match found for transfer model 'Hm_model_Unetr2' in target 'Hmito' - removing from result
# Info: No match found for transfer model 'Rm_model4' in target 'Rmito' - removing from result
# Info: No match found for transfer model 'Rm_model_NA2' in target 'Rmito' - removing from result
# Info: No match found for transfer model 'Rm_model_Res1' in target 'Rmito' - removing from result
# Info: No match found for transfer model 'Rm_model_Unetr2' in target 'Rmito' - removing from result
# Processing: LEEP
# Number of targets: 4
#   Target 1: EPFL
#   Target 2: Hmito
#   Target 3: Rmito
#   Target 4: VNC
#                 kt  kt pval  s rho  s rho pval    pr  pr pval
# Task targets
# Mito EPFL     0.44     0.17   0.72        0.02  0.56     0.01
#      Hmito    0.10     0.78  -0.04        0.85 -0.09     0.77
#      Rmito    0.39     0.23   0.36        0.25  0.16     0.51
#      VNC      0.37     0.23   0.41        0.19  0.27     0.24
# Loaded Transfer metric results from: /scratch/talks/sampled_features/semantic_segmentation/mitochondria/transfer_metric_results/mitochondria_Gaussian_LEEP.json
# Experiment: mitochondria_Gaussian_LEEP
# Targets: 4 (EPFL, Hmito, Rmito, VNC)
# Source models: 15
# Total transfers: 57
# Info: No match found for transfer model 'E_model5' in target 'EPFL' - removing from result
# Info: No match found for transfer model 'E_model_NA2' in target 'EPFL' - removing from result
# Info: No match found for transfer model 'E_model_Res1' in target 'EPFL' - removing from result
# Info: No match found for transfer model 'E_model_Unetr2' in target 'EPFL' - removing from result
# Info: No match found for transfer model 'Hm_model4' in target 'Hmito' - removing from result
# Info: No match found for transfer model 'Hm_model_NA2' in target 'Hmito' - removing from result
# Info: No match found for transfer model 'Hm_model_Res1' in target 'Hmito' - removing from result
# Info: No match found for transfer model 'Hm_model_Unetr2' in target 'Hmito' - removing from result
# Info: No match found for transfer model 'Rm_model4' in target 'Rmito' - removing from result
# Info: No match found for transfer model 'Rm_model_NA2' in target 'Rmito' - removing from result
# Info: No match found for transfer model 'Rm_model_Res1' in target 'Rmito' - removing from result
# Info: No match found for transfer model 'Rm_model_Unetr2' in target 'Rmito' - removing from result
# Processing: Gaussian_LEEP
# Number of targets: 4
#   Target 1: EPFL
#   Target 2: Hmito
#   Target 3: Rmito
#   Target 4: VNC
#                 kt  kt pval  s rho  s rho pval    pr  pr pval
# Task targets
# Mito EPFL     0.11     0.75   0.15        0.68  0.09     0.77
#      Hmito    0.10     0.76  -0.21        0.54 -0.20     0.43
#      Rmito    0.45     0.17   0.45        0.17  0.38     0.13
#      VNC     -0.02     0.95  -0.03        0.92  0.03     0.94
# Loaded Transfer metric results from: /scratch/talks/sampled_features/semantic_segmentation/mitochondria/transfer_metric_results/mitochondria_Hscore.json
# Experiment: mitochondria_Hscore
# Targets: 4 (EPFL, Hmito, Rmito, VNC)
# Source models: 15
# Total transfers: 57
# Info: No match found for transfer model 'E_model5' in target 'EPFL' - removing from result
# Info: No match found for transfer model 'E_model_NA2' in target 'EPFL' - removing from result
# Info: No match found for transfer model 'E_model_Res1' in target 'EPFL' - removing from result
# Info: No match found for transfer model 'E_model_Unetr2' in target 'EPFL' - removing from result
# Info: No match found for transfer model 'Hm_model4' in target 'Hmito' - removing from result
# Info: No match found for transfer model 'Hm_model_NA2' in target 'Hmito' - removing from result
# Info: No match found for transfer model 'Hm_model_Res1' in target 'Hmito' - removing from result
# Info: No match found for transfer model 'Hm_model_Unetr2' in target 'Hmito' - removing from result
# Info: No match found for transfer model 'Rm_model4' in target 'Rmito' - removing from result
# Info: No match found for transfer model 'Rm_model_NA2' in target 'Rmito' - removing from result
# Info: No match found for transfer model 'Rm_model_Res1' in target 'Rmito' - removing from result
# Info: No match found for transfer model 'Rm_model_Unetr2' in target 'Rmito' - removing from result
# Processing: Hscore
# Number of targets: 4
#   Target 1: EPFL
#   Target 2: Hmito
#   Target 3: Rmito
#   Target 4: VNC
#                 kt  kt pval  s rho  s rho pval    pr  pr pval
# Task targets
# Mito EPFL     0.20     0.56   0.09        0.78 -0.02     0.98
#      Hmito    0.21     0.54   0.42        0.16  0.27     0.28
#      Rmito    0.41     0.20   0.53        0.10  0.45     0.05
#      VNC      0.17     0.60   0.28        0.37  0.15     0.52
# Loaded Transfer metric results from: /scratch/talks/sampled_features/semantic_segmentation/mitochondria/transfer_metric_results/mitochondria_Regularized_Hscore.json
# Experiment: mitochondria_Regularized_Hscore
# Targets: 4 (EPFL, Hmito, Rmito, VNC)
# Source models: 15
# Total transfers: 57
# Info: No match found for transfer model 'E_model5' in target 'EPFL' - removing from result
# Info: No match found for transfer model 'E_model_NA2' in target 'EPFL' - removing from result
# Info: No match found for transfer model 'E_model_Res1' in target 'EPFL' - removing from result
# Info: No match found for transfer model 'E_model_Unetr2' in target 'EPFL' - removing from result
# Info: No match found for transfer model 'Hm_model4' in target 'Hmito' - removing from result
# Info: No match found for transfer model 'Hm_model_NA2' in target 'Hmito' - removing from result
# Info: No match found for transfer model 'Hm_model_Res1' in target 'Hmito' - removing from result
# Info: No match found for transfer model 'Hm_model_Unetr2' in target 'Hmito' - removing from result
# Info: No match found for transfer model 'Rm_model4' in target 'Rmito' - removing from result
# Info: No match found for transfer model 'Rm_model_NA2' in target 'Rmito' - removing from result
# Info: No match found for transfer model 'Rm_model_Res1' in target 'Rmito' - removing from result
# Info: No match found for transfer model 'Rm_model_Unetr2' in target 'Rmito' - removing from result
# Processing: Regularized_Hscore
# Number of targets: 4
#   Target 1: EPFL
#   Target 2: Hmito
#   Target 3: Rmito
#   Target 4: VNC
#                 kt  kt pval  s rho  s rho pval    pr  pr pval
# Task targets
# Mito EPFL     0.20     0.56   0.09        0.79 -0.02     1.00
#      Hmito    0.21     0.54   0.40        0.21  0.24     0.35
#      Rmito    0.41     0.21   0.53        0.09  0.45     0.03
#      VNC      0.17     0.60   0.28        0.38  0.15     0.57
# Loaded Transfer metric results from: /scratch/talks/sampled_features/semantic_segmentation/mitochondria/transfer_metric_results/mitochondria_NCTI.json
# Experiment: mitochondria_NCTI
# Targets: 4 (EPFL, Hmito, Rmito, VNC)
# Source models: 15
# Total transfers: 57
# Info: No match found for transfer model 'E_model5' in target 'EPFL' - removing from result
# Info: No match found for transfer model 'E_model_NA2' in target 'EPFL' - removing from result
# Info: No match found for transfer model 'E_model_Res1' in target 'EPFL' - removing from result
# Info: No match found for transfer model 'E_model_Unetr2' in target 'EPFL' - removing from result
# Info: No match found for transfer model 'Hm_model4' in target 'Hmito' - removing from result
# Info: No match found for transfer model 'Hm_model_NA2' in target 'Hmito' - removing from result
# Info: No match found for transfer model 'Hm_model_Res1' in target 'Hmito' - removing from result
# Info: No match found for transfer model 'Hm_model_Unetr2' in target 'Hmito' - removing from result
# Info: No match found for transfer model 'Rm_model4' in target 'Rmito' - removing from result
# Info: No match found for transfer model 'Rm_model_NA2' in target 'Rmito' - removing from result
# Info: No match found for transfer model 'Rm_model_Res1' in target 'Rmito' - removing from result
# Info: No match found for transfer model 'Rm_model_Unetr2' in target 'Rmito' - removing from result
# Processing: NCTI
# Number of targets: 4
#   Target 1: EPFL
#   Target 2: Hmito
#   Target 3: Rmito
#   Target 4: VNC
#                 kt  kt pval  s rho  s rho pval    pr  pr pval
# Task targets
# Mito EPFL     0.08     0.82  -0.21        0.55 -0.16     0.54
#      Hmito   -0.24     0.49  -0.24        0.47 -0.09     0.77
#      Rmito    0.37     0.26   0.26        0.40  0.16     0.61
#      VNC      0.04     0.89  -0.01        0.98  0.00     1.00
# Loaded Transfer metric results from: /scratch/talks/sampled_features/semantic_segmentation/mitochondria/transfer_metric_results/mitochondria_LogME.json
# Experiment: mitochondria_LogME
# Targets: 4 (EPFL, Hmito, Rmito, VNC)
# Source models: 15
# Total transfers: 57
# Info: No match found for transfer model 'E_model5' in target 'EPFL' - removing from result
# Info: No match found for transfer model 'E_model_NA2' in target 'EPFL' - removing from result
# Info: No match found for transfer model 'E_model_Res1' in target 'EPFL' - removing from result
# Info: No match found for transfer model 'E_model_Unetr2' in target 'EPFL' - removing from result
# Info: No match found for transfer model 'Hm_model4' in target 'Hmito' - removing from result
# Info: No match found for transfer model 'Hm_model_NA2' in target 'Hmito' - removing from result
# Info: No match found for transfer model 'Hm_model_Res1' in target 'Hmito' - removing from result
# Info: No match found for transfer model 'Hm_model_Unetr2' in target 'Hmito' - removing from result
# Info: No match found for transfer model 'Rm_model4' in target 'Rmito' - removing from result
# Info: No match found for transfer model 'Rm_model_NA2' in target 'Rmito' - removing from result
# Info: No match found for transfer model 'Rm_model_Res1' in target 'Rmito' - removing from result
# Info: No match found for transfer model 'Rm_model_Unetr2' in target 'Rmito' - removing from result
# Processing: LogME
# Number of targets: 4
#   Target 1: EPFL
#   Target 2: Hmito
#   Target 3: Rmito
#   Target 4: VNC
#                 kt  kt pval  s rho  s rho pval    pr  pr pval
# Task targets
# Mito EPFL     0.16     0.64   0.05        0.87 -0.13     0.68
#      Hmito   -0.08     0.82  -0.01        0.99 -0.02     0.97
#      Rmito    0.03     0.94   0.41        0.23  0.35     0.14
#      VNC      0.29     0.36   0.13        0.63  0.00     1.00
