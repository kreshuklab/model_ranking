# %%
import h5py
import matplotlib.pyplot as plt

# %%
path = "/g/kreshuk/talks/consistency_results/patch_segmentation/nuclei/BBBC039_to_Hoechst_gap/consistency/P_1/BC_model4/norm_50_980/none/metric_summary.h5"
with h5py.File(path, "r") as f:
    f1_eval = f["F1_eval"][:]
    f1_eval_median = f["F1_eval_median"][:]

print(f1_eval)
print(f1_eval_median)

# %%
path = "/g/kreshuk/talks/consistency_results/patch_segmentation/nuclei/HeLaNuc_to_Hoechst_gap/consistency/P_1/HN_model1/norm_50_980/none/predictions/MFGTMPcx7_170702000001_G14f03d0_predictions.h5"
with h5py.File(path, "r") as f:
    print(f.keys())
    f1_score = f["hard_f1"][:]
    predictions = f["predictions"][:]
    segmentation = f["segmentation"][:]
# Out:
# <KeysViewHDF5 ['hard_f1', 'predictions', 'segmentation']>

# %%
f1_score
# Out:
# array([0.98904574, 0.10637216], dtype=float32)

# %%
segmentation.shape
# Out:
# (1104, 1104)

# %%
plt.imshow(segmentation)
plt.show()
