# %%
import imageio.v3 as imageio

# %%
path = "/g/kreshuk/talks/data/S-BIAD634/dataset/rawimages/otherspecimen_0.tif"
img = imageio.imread(path)
print(img.shape)
# Out:
# (1024, 1280)

# %%
(401, 512, 512)
(240, 512, 512)
(400, 512, 512)
(380, 512, 512)
(121, 512, 512)
(121, 512, 512)
(121, 512, 512)
(121, 512, 512)
(121, 512, 512)
(121, 512, 512)
