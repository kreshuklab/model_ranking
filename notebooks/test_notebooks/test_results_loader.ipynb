# %%
from model_ranking.results import get_summary_results
from typing import List, Dict, Tuple
from model_ranking.utils import load_h5

# %%
selected_augmentations = {
    "none": [""],
    "DO": ["a01"],
}
source_models = {
    "BBBC039": "BC_IN_model2",
}
per_target_norms: Dict[str, List[Tuple[float, float]]] = {
    "BBBC039": [(5.0, 98.0)]
}
result_folders = {
    "BBBC039": "test"
}
consis_keys = {
    "BBBC039": "ARE_consis"
}
target_datasets = [
    "BBBC039",
]
source_datasets = [
    "BBBC039",
]

# %%
selected_augmentations = {
    "none": [""],
    "DO": ["a01"],
}
source_models = {
    "BBBC039": "BC_model4",
}
result_folders = {
    "BBBC039": "test"
}
consis_keys = {
    "BBBC039": "EI_consis"
}
target_datasets = [
    "BBBC039",
]
source_datasets = [
    "BBBC039",
]

# %%
consis_per_str, perf_per_str, NA_perf = get_summary_results(
        source_data=source_datasets, 
        target_data=target_datasets, 
        source_models=source_models, 
        selected_augmentations=selected_augmentations,
        consis_keys=consis_keys,
        perf_key="f1_score",
        per_target_norms=True,
        result_folders=result_folders,
        approach="feature_perturbation_consistency",
        consis_postfix= "std_per_alpha",
        perf_postfix="median",
        base_seg_dir="/g/kreshuk/talks/model_ranking/scripts/test_scripts/sweep3",
    )
# Out:
# Source: BBBC039
# 100%|██████████| 1/1 [00:00<00:00, 142.10it/s]
